# %%
import matplotlib.pyplot as plt

# Depth
depth = [1, 2, 3, 4, 5]

# Computational Complexity for Connect 4 (C4)




c4_complexity = [6, 36, 216, 1296, 7776]

# Computational Complexity for Connect 4 Twist and Turn (C4TT)
c4tt_complexity = [18, 540, 29160, 2974320, 588915360]

# Complexity Ratio (C4TT / C4)
complexity_ratio = [c4tt / c4 for c4tt, c4 in zip(c4tt_complexity, c4_complexity)]

# Plot
plt.figure(figsize=(10, 6))


plt.plot(depth, complexity_ratio, marker='o', label='Complexity Ratio (C4TT / C4)')

plt.xlabel('Depth')
plt.ylabel('Computational Complexity ')
plt.title('Computational Complexity Comparison: Connect 4 vs. Connect 4 Twist and Turn')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Depth
depth = [1, 2, 3, 4, 5]

# Computational Complexity for Connect 4 (C4)
c4_complexity = [6, 36, 216, 1296, 7776]

# Computational Complexity for Connect 4 Twist and Turn (C4TT)
c4tt_complexity = [18, 540, 29160, 2974320, 588915360]

# Complexity Ratio (C4TT / C4)
complexity_ratio = [c4tt / c4 for c4tt, c4 in zip(c4tt_complexity, c4_complexity)]

# Plot
fig, axs = plt.subplots(2, 1, figsize=(10, 12))

# Plot for C4
axs[0].plot(depth, c4_complexity, marker='o', label='Connect 4 (C4)')
axs[0].set_xlabel('Depth')
axs[0].set_ylabel('Node Count')
axs[0].set_title('Connect 4 (C4)')
axs[0].legend()
axs[0].grid(True)

# Plot for C4TT
axs[1].plot(depth, c4tt_complexity, marker='o', label='Connect 4 Twist and Turn (C4TT)')
axs[1].set_xlabel('Depth')
axs[1].set_ylabel('Node Count')
axs[1].set_title('Connect 4 Twist and Turn (C4TT)')
axs[1].legend()
axs[1].grid(True)

plt.tight_layout()
plt.show()
